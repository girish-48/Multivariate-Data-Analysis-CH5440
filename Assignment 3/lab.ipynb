# %%
import matplotlib.pyplot as plt

# %%
T = [ 8,12,16,20 ]
BP = [ 1.287, 1.92, 2.538, 3.267 ]
sfc = [ 429.73, 313.83, 283.64, 242.58 ]
bte = [ 19.94, 27.31, 30.22, 35.33 ]
ma  = [ 26.03, 25.6, 25.16, 24.78 ]
mf  = [ 0.5533, 0.602, 0.72, 0.793 ]
afr = [ 47.04, 42.53, 34.94, 31.26 ]
vef = [ 88.77, 87.93, 87.05, 83.26 ]
egt = [ 166,199,232,269 ]
NOx = [ 90,178,331,578 ]
CO  = [ 0.08,0.06,0.07,0.04 ]
HC  = [ 5,5,5,5 ]
FSN = [ 0.136,0.27,0.474,0.932 ]

# %%
title = 'NOx and Hydrocarbon concentration vs Brake Power'
ylabel = ' Concentration in ppm'

plt.plot(BP, NOx, marker='.')
plt.plot(BP, HC, marker='.')
plt.grid()
plt.legend(['NOx', 'Hydrocarbon'])
plt.title(title)
plt.xlabel('Brake Power (kW)')
plt.ylabel(ylabel)
# Out:
# Text(0, 0.5, ' Concentration in ppm')

# %%
import numpy.linalg as linal
import numpy as np

# %%
a = np.array([[4],[0],[0]])
b = np.array([[0],[2],[0]])
c = np.array([[4,0],[0,2],[0,0]])

# %%
linal.svd(a)
# Out:
# (array([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]]),
#  array([4.]),
#  array([[1.]]))

# %%
linal.svd(b)
# Out:
# (array([[ 0., -1.,  0.],
#         [ 1.,  0.,  0.],
#         [ 0.,  0.,  1.]]),
#  array([2.]),
#  array([[1.]]))

# %%
linal.svd(c)
# Out:
# (array([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]]),
#  array([4., 2.]),
#  array([[1., 0.],
#         [0., 1.]]))

# %%
linal.matrix_rank(c)
# Out:
# 2

# %%
a@a.T
# Out:
# array([[16,  0,  0],
#        [ 0,  0,  0],
#        [ 0,  0,  0]])

# %%
import numpy as np

# %%
a = np.array([ 9, 8, 2, 5, 1, 10, 4, 2, 1, 0 ])
print(np.argpartition(a,5))
# Out:
# [8 9 4 2 7 6 3 1 5 0]

# %%
a[np.argsort(a[np.argpartition(a,5)])]
# Out:
# array([ 8,  9,  2,  5,  1, 10,  4,  2,  0,  1])

# %%
np.argsort(a)
# Out:
# array([9, 4, 8, 2, 7, 6, 3, 1, 0, 5])

# %%
a
# Out:
# array([ 9,  8,  2,  5,  1, 10,  4,  2,  1,  0])

# %%
np.sort(a)
# Out:
# array([ 0,  1,  1,  2,  2,  4,  5,  8,  9, 10])
